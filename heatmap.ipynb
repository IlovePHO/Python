# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.random.random((12, 12))
plt.imshow(data)

plt.title("2D Heat Map")
plt.show()

# %%
data - np.random.random((12, 12))
plt.imshow(data, cmap='autumn')

plt.title("HeatMap with warm color")
plt.show()

# %%
data = np.random.random((12, 12))
plt.imshow(data, cmap="autumn", interpolation='nearest')

plt.colorbar()

plt.title('Heatmap with colorabar')
plt.show()

# %%
import matplotlib.colors as colors

# %%
data = np.random.randint(0, 100, size=(8, 8))

color_list = ['#0099ff', '#33cc33']
cmap = colors.ListedColormap(color_list)

plt.imshow(data, cmap=cmap, vmin=0,\
           vmax=100, extent=[0,8,0,8])

for i in range(8):
    for j in range(8):
        plt.annotate(str(data[i][j]), xy=(j+0.5, i+0.5),
                     ha='center', va='center', color='white')
    

cbar = plt.colorbar(ticks=[0,50,100])
cbar.ax.set_yticklabels(['Low', 'Medium', 'High'])

plt.title("Customized heatmap with annotations")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

plt.show()

# %%
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
    
# generating 2-D 10x10 matrix of random numbers 
# from 1 to 100 
data = np.random.randint(low=1, 
                         high=100, 
                         size=(10, 10)) 
    
# plotting the heatmap 
hm = sns.heatmap(data=data, 
                annot=True) 
    
# displaying the plotted heatmap 
plt.show()

# %% [markdown]
# Cube 3D

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

axes = [5,5,5]

data = np.ones(axes, dtype=np.bool)

alpha = 0.9

colors = np.empty(axes + [4], dtype=np.float32)

colors[:] = [1, 0, 0, alpha]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.voxels(data, facecolors=colors)
# Out:
# {(np.int64(0),
#   np.int64(0),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0f9152b0>,
#  (np.int64(0),
#   np.int64(0),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fb4dbd0>,
#  (np.int64(0),
#   np.int64(1),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fb4dd10>,
#  (np.int64(0),
#   np.int64(1),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fb4de50>,
#  (np.int64(0),
#   np.int64(2),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fb4df90>,
#  (np.int64(0),
#   np.int64(2),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fb4e0d0>,
#  (np.int64(0),
#   np.int64(3),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fb4e210>,
#  (np.int64(0),
#   np.int64(3),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fb4e350>,
#  (np.int64(0),
#   np.int64(4),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fb4e490>,
#  (np.int64(0),
#   np.int64(4),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fb4e5d0>,
#  (np.int64(1),
#   np.int64(0),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fb4e710>,
#  (np.int64(1),
#   np.int64(0),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fb4e850>,
#  (np.int64(1),
#   np.int64(1),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fb4e990>,
#  (np.int64(1),
#   np.int64(1),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fb4ead0>,
#  (np.int64(1),
#   np.int64(2),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fb4ec10>,
#  (np.int64(1),
#   np.int64(2),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fb4ed50>,
#  (np.int64(1),
#   np.int64(3),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fb4ee90>,
#  (np.int64(1),
#   np.int64(3),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fb4efd0>,
#  (np.int64(1),
#   np.int64(4),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fb4f110>,
#  (np.int64(1),
#   np.int64(4),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fb4f250>,
#  (np.int64(2),
#   np.int64(0),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fb4f390>,
#  (np.int64(2),
#   np.int64(0),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fb4f4d0>,
#  (np.int64(2),
#   np.int64(1),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fb4f610>,
#  (np.int64(2),
#   np.int64(1),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fb4f750>,
#  (np.int64(2),
#   np.int64(2),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fb4f890>,
#  (np.int64(2),
#   np.int64(2),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fb4f9d0>,
#  (np.int64(2),
#   np.int64(3),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fb4fb10>,
#  (np.int64(2),
#   np.int64(3),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fb4fc50>,
#  (np.int64(2),
#   np.int64(4),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fb4fd90>,
#  (np.int64(2),
#   np.int64(4),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fb4fed0>,
#  (np.int64(3),
#   np.int64(0),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba0050>,
#  (np.int64(3),
#   np.int64(0),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba0190>,
#  (np.int64(3),
#   np.int64(1),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba02d0>,
#  (np.int64(3),
#   np.int64(1),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba0550>,
#  (np.int64(3),
#   np.int64(2),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba0690>,
#  (np.int64(3),
#   np.int64(2),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba07d0>,
#  (np.int64(3),
#   np.int64(3),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba0910>,
#  (np.int64(3),
#   np.int64(3),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba0a50>,
#  (np.int64(3),
#   np.int64(4),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba0b90>,
#  (np.int64(3),
#   np.int64(4),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba0cd0>,
#  (np.int64(4),
#   np.int64(0),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba0e10>,
#  (np.int64(4),
#   np.int64(0),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba0410>,
#  (np.int64(4),
#   np.int64(1),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba0f50>,
#  (np.int64(4),
#   np.int64(1),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba1090>,
#  (np.int64(4),
#   np.int64(2),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba11d0>,
#  (np.int64(4),
#   np.int64(2),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba1310>,
#  (np.int64(4),
#   np.int64(3),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba1450>,
#  (np.int64(4),
#   np.int64(3),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba1590>,
#  (np.int64(4),
#   np.int64(4),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba16d0>,
#  (np.int64(4),
#   np.int64(4),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba1810>,
#  (np.int64(0),
#   np.int64(0),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba1950>,
#  (np.int64(4),
#   np.int64(0),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba1a90>,
#  (np.int64(0),
#   np.int64(0),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba1bd0>,
#  (np.int64(4),
#   np.int64(0),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba1d10>,
#  (np.int64(0),
#   np.int64(0),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba1e50>,
#  (np.int64(4),
#   np.int64(0),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba1f90>,
#  (np.int64(0),
#   np.int64(1),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba20d0>,
#  (np.int64(4),
#   np.int64(1),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba2210>,
#  (np.int64(0),
#   np.int64(1),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba2350>,
#  (np.int64(4),
#   np.int64(1),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba2490>,
#  (np.int64(0),
#   np.int64(1),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba25d0>,
#  (np.int64(4),
#   np.int64(1),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba2710>,
#  (np.int64(0),
#   np.int64(2),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba2850>,
#  (np.int64(4),
#   np.int64(2),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba2990>,
#  (np.int64(0),
#   np.int64(2),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba2ad0>,
#  (np.int64(4),
#   np.int64(2),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba2c10>,
#  (np.int64(0),
#   np.int64(2),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba2d50>,
#  (np.int64(4),
#   np.int64(2),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba2e90>,
#  (np.int64(0),
#   np.int64(3),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba2fd0>,
#  (np.int64(4),
#   np.int64(3),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba3110>,
#  (np.int64(0),
#   np.int64(3),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba3250>,
#  (np.int64(4),
#   np.int64(3),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba3390>,
#  (np.int64(0),
#   np.int64(3),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba34d0>,
#  (np.int64(4),
#   np.int64(3),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba3610>,
#  (np.int64(0),
#   np.int64(4),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba3750>,
#  (np.int64(4),
#   np.int64(4),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba3890>,
#  (np.int64(0),
#   np.int64(4),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba39d0>,
#  (np.int64(4),
#   np.int64(4),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba3b10>,
#  (np.int64(0),
#   np.int64(4),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba3c50>,
#  (np.int64(4),
#   np.int64(4),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba3d90>,
#  (np.int64(1),
#   np.int64(0),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fba3ed0>,
#  (np.int64(1),
#   np.int64(4),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fd7c050>,
#  (np.int64(2),
#   np.int64(0),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fd7c190>,
#  (np.int64(2),
#   np.int64(4),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fd7c2d0>,
#  (np.int64(3),
#   np.int64(0),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fd7c410>,
#  (np.int64(3),
#   np.int64(4),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fd7c550>,
#  (np.int64(1),
#   np.int64(0),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fd7c690>,
#  (np.int64(1),
#   np.int64(4),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fd7c7d0>,
#  (np.int64(2),
#   np.int64(0),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fd7c910>,
#  (np.int64(2),
#   np.int64(4),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fd7ca50>,
#  (np.int64(3),
#   np.int64(0),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fd7cb90>,
#  (np.int64(3),
#   np.int64(4),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fd7ccd0>,
#  (np.int64(1),
#   np.int64(0),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fd7ce10>,
#  (np.int64(1),
#   np.int64(4),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fd7cf50>,
#  (np.int64(2),
#   np.int64(0),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fd7d090>,
#  (np.int64(2),
#   np.int64(4),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fd7d1d0>,
#  (np.int64(3),
#   np.int64(0),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fd7d310>,
#  (np.int64(3),
#   np.int64(4),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fd7d450>}

# %%
# Create axis
axes = [5, 5, 5]
# Create Data
data = np.ones(axes, dtype=np.bool)
# Control Transparency
alpha = 0.9
# Control colour
colors = np.empty(axes + [4], dtype=np.float32)

colors[0] = [1, 0, 0, alpha]
colors[1] = [0, 1, 0, alpha]
colors[2] = [0, 0, 1, alpha]
colors[3] = [1, 1, 0, alpha]
colors[4] = [1, 1, 1, alpha]
# Plot figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')


# Voxels is used to customizations of
# the sizes, positions and colors.
ax.voxels(data, facecolors=colors, edgecolors='grey')
# Out:
# {(np.int64(0),
#   np.int64(0),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc4910>,
#  (np.int64(0),
#   np.int64(0),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc4a50>,
#  (np.int64(0),
#   np.int64(1),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc4b90>,
#  (np.int64(0),
#   np.int64(1),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc4cd0>,
#  (np.int64(0),
#   np.int64(2),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc4e10>,
#  (np.int64(0),
#   np.int64(2),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc4f50>,
#  (np.int64(0),
#   np.int64(3),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc5090>,
#  (np.int64(0),
#   np.int64(3),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc51d0>,
#  (np.int64(0),
#   np.int64(4),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc5310>,
#  (np.int64(0),
#   np.int64(4),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc5450>,
#  (np.int64(1),
#   np.int64(0),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc5590>,
#  (np.int64(1),
#   np.int64(0),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc56d0>,
#  (np.int64(1),
#   np.int64(1),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc5810>,
#  (np.int64(1),
#   np.int64(1),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc5950>,
#  (np.int64(1),
#   np.int64(2),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc5a90>,
#  (np.int64(1),
#   np.int64(2),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc5bd0>,
#  (np.int64(1),
#   np.int64(3),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc5d10>,
#  (np.int64(1),
#   np.int64(3),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc5e50>,
#  (np.int64(1),
#   np.int64(4),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc5f90>,
#  (np.int64(1),
#   np.int64(4),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc60d0>,
#  (np.int64(2),
#   np.int64(0),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc6210>,
#  (np.int64(2),
#   np.int64(0),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc6350>,
#  (np.int64(2),
#   np.int64(1),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc6490>,
#  (np.int64(2),
#   np.int64(1),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc65d0>,
#  (np.int64(2),
#   np.int64(2),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc6710>,
#  (np.int64(2),
#   np.int64(2),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc6850>,
#  (np.int64(2),
#   np.int64(3),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc6990>,
#  (np.int64(2),
#   np.int64(3),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc6ad0>,
#  (np.int64(2),
#   np.int64(4),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc6c10>,
#  (np.int64(2),
#   np.int64(4),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc6d50>,
#  (np.int64(3),
#   np.int64(0),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc6e90>,
#  (np.int64(3),
#   np.int64(0),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc6fd0>,
#  (np.int64(3),
#   np.int64(1),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc7110>,
#  (np.int64(3),
#   np.int64(1),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc7390>,
#  (np.int64(3),
#   np.int64(2),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc74d0>,
#  (np.int64(3),
#   np.int64(2),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc7610>,
#  (np.int64(3),
#   np.int64(3),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc7750>,
#  (np.int64(3),
#   np.int64(3),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc7890>,
#  (np.int64(3),
#   np.int64(4),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc79d0>,
#  (np.int64(3),
#   np.int64(4),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc7b10>,
#  (np.int64(4),
#   np.int64(0),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc7c50>,
#  (np.int64(4),
#   np.int64(0),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc7250>,
#  (np.int64(4),
#   np.int64(1),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc7d90>,
#  (np.int64(4),
#   np.int64(1),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0ffc7ed0>,
#  (np.int64(4),
#   np.int64(2),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe24050>,
#  (np.int64(4),
#   np.int64(2),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe24190>,
#  (np.int64(4),
#   np.int64(3),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe242d0>,
#  (np.int64(4),
#   np.int64(3),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe24410>,
#  (np.int64(4),
#   np.int64(4),
#   np.int64(0)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe24550>,
#  (np.int64(4),
#   np.int64(4),
#   np.int64(4)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe24690>,
#  (np.int64(0),
#   np.int64(0),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe247d0>,
#  (np.int64(4),
#   np.int64(0),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe24910>,
#  (np.int64(0),
#   np.int64(0),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe24a50>,
#  (np.int64(4),
#   np.int64(0),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe24b90>,
#  (np.int64(0),
#   np.int64(0),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe24cd0>,
#  (np.int64(4),
#   np.int64(0),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe24e10>,
#  (np.int64(0),
#   np.int64(1),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe24f50>,
#  (np.int64(4),
#   np.int64(1),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe25090>,
#  (np.int64(0),
#   np.int64(1),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe251d0>,
#  (np.int64(4),
#   np.int64(1),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe25310>,
#  (np.int64(0),
#   np.int64(1),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe25450>,
#  (np.int64(4),
#   np.int64(1),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe25590>,
#  (np.int64(0),
#   np.int64(2),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe256d0>,
#  (np.int64(4),
#   np.int64(2),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe25810>,
#  (np.int64(0),
#   np.int64(2),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe25950>,
#  (np.int64(4),
#   np.int64(2),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe25a90>,
#  (np.int64(0),
#   np.int64(2),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe25bd0>,
#  (np.int64(4),
#   np.int64(2),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe25d10>,
#  (np.int64(0),
#   np.int64(3),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe25e50>,
#  (np.int64(4),
#   np.int64(3),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe25f90>,
#  (np.int64(0),
#   np.int64(3),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe260d0>,
#  (np.int64(4),
#   np.int64(3),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe26210>,
#  (np.int64(0),
#   np.int64(3),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe26350>,
#  (np.int64(4),
#   np.int64(3),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe26490>,
#  (np.int64(0),
#   np.int64(4),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe265d0>,
#  (np.int64(4),
#   np.int64(4),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe26710>,
#  (np.int64(0),
#   np.int64(4),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe26850>,
#  (np.int64(4),
#   np.int64(4),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe26990>,
#  (np.int64(0),
#   np.int64(4),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe26ad0>,
#  (np.int64(4),
#   np.int64(4),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe26c10>,
#  (np.int64(1),
#   np.int64(0),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe26d50>,
#  (np.int64(1),
#   np.int64(4),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe26e90>,
#  (np.int64(2),
#   np.int64(0),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe26fd0>,
#  (np.int64(2),
#   np.int64(4),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe27110>,
#  (np.int64(3),
#   np.int64(0),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe27250>,
#  (np.int64(3),
#   np.int64(4),
#   np.int64(1)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe27390>,
#  (np.int64(1),
#   np.int64(0),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe274d0>,
#  (np.int64(1),
#   np.int64(4),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe27610>,
#  (np.int64(2),
#   np.int64(0),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe27750>,
#  (np.int64(2),
#   np.int64(4),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe27890>,
#  (np.int64(3),
#   np.int64(0),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe279d0>,
#  (np.int64(3),
#   np.int64(4),
#   np.int64(2)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe27b10>,
#  (np.int64(1),
#   np.int64(0),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe27c50>,
#  (np.int64(1),
#   np.int64(4),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe27d90>,
#  (np.int64(2),
#   np.int64(0),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fe27ed0>,
#  (np.int64(2),
#   np.int64(4),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fed0050>,
#  (np.int64(3),
#   np.int64(0),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fed0190>,
#  (np.int64(3),
#   np.int64(4),
#   np.int64(3)): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1fb0fed02d0>}

# %%
axes = [5, 5, 5]
data = np.ones(axes, dtype=np.bool)
 
colors = np.empty(axes + [4], dtype=np.float32)
 
# Control Transparency
alpha = .7
 
# Control colors
colors[0] = [1, 0, 0, alpha]
colors[1] = [0, 1, 0, alpha]
colors[2] = [0, 0, 1, alpha]
colors[3] = [1, 1, 0, alpha]
colors[4] = [0, 1, 1, alpha]
 
# set all internal colors to 
# black with alpha=1
colors[1:-1, 1:-1, 1:-1, 0:3] = 0
colors[1:-1, 1:-1, 1:-1, 3] = 1
 
# Plot figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
 
# Control number of slice
data[-1] = True
data[-2] = False
data[-3] = False
data[-4] = False
data[-5] = True
 
# Voxels is used to customizations of 
# the sizes, positions and colors.
ax.voxels(data, facecolors=colors, edgecolors='pink')
 
# it can be used to change the axes view
ax.view_init(100, 0)

# %%
axes = [5, 5, 5]
data = np.ones(axes, dtype=np.bool)
 
colors = np.empty(axes + [4], dtype=np.float32)
 
# Control Transparency
alpha = .7
 
# Control colors
colors[0] = [1, 0, 0, alpha]
colors[1] = [0, 1, 0, alpha]
colors[2] = [0, 0, 1, alpha]
colors[3] = [1, 1, 0, alpha]
colors[4] = [0, 1, 1, alpha]
 
# set all internal colors to 
# black with alpha=1
colors[1:-1, 1:-1, 1:-1, 0:3] = 0
colors[1:-1, 1:-1, 1:-1, 3] = 1
 
# Plot figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
 
# Control number of slice
data[-1] = 1
data[-2] = False
data[-3] = False
data[-4] = False
data[-5] = True
 
# Voxels is used to customizations 
# of the sizes, positions and colors.
ax.voxels(data, facecolors=colors, edgecolors='pink')
 
# it can be used to change the axes view
ax.view_init(100, 90)
